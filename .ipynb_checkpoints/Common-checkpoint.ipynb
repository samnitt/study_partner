# %%
import pandas as pd

# %%
df1 = pd.read_excel('Common2.xlsx')
elective = pd.read_excel('elective.xlsx')
student_details = pd.read_excel('student_details.xlsx',index_col = 0)
repeat = pd.read_excel('repeat.xlsx',index_col = 0)
button_labels = [f"Button {i}" for i in range(1, 21)]
electivefive = elective['Q5'].tolist()
electivesix = elective['Q6'].tolist()
electiveseven = elective['Q7'].tolist()
button = student_details['Roll'].tolist()
df1 = df1.replace("Y","1")
df1 = df1.fillna(0)
df2 = df1["Tamil"].astype(int) + df1["Aravinthan"].astype(int)
selected_buttons1 = []
selected_buttons1 = 'EPGP-15A-002'

# %%
(df2 == 2).sum()
# Out:
# 3

# %%
def countofcommon (Name1, Name2):
    df3 = df1[Name1].astype(int) + df1[Name2].astype(int)
    total = (df3 == 2).sum()
    if Name1 == Name2:
        total = 0
    return total

# %%
countofcommon("Arul","Arul")
# Out:
# 0

# %%
student_details
# Out:
#              Roll          Name  \
# 0    EPGP-15A-001  EPGP-15A-001
# 1    EPGP-15A-002  EPGP-15A-002
# 2    EPGP-15A-003  EPGP-15A-003
# 3    EPGP-15A-004  EPGP-15A-004
# 4    EPGP-15A-005  EPGP-15A-005
# ..            ...           ...
# 545  EPGP-15E-106  EPGP-15E-106
# 546  EPGP-15E-107  EPGP-15E-107
# 547  EPGP-15E-108  EPGP-15E-108
# 548  EPGP-15E-109  EPGP-15E-109
# 549  EPGP-15E-110  EPGP-15E-110
#
#                                                   Q5_1  \
# 0                                                  NaN
# 1    EEC-03-Agent-Based Modelling for Business and ...
# 2                 EEC-02-Introduction to Public Policy
# 3                                                  NaN
# 4                                                  NaN
# ..                                                 ...
# 545                                                NaN
# 546                                                NaN
# 547                                                NaN
# 548                                                NaN
# 549                                                NaN
#
#                                                   Q5_2  \
# 0                                                  NaN
# 1    EHLM-01-Advanced Corporate Communication: The ...
# 2    EEC-03-Agent-Based Modelling for Business and ...
# 3                                                  NaN
# 4                                                  NaN
# ..                                                 ...
# 545                                                NaN
# 546                                                NaN
# 547                                                NaN
# 548                                                NaN
# 549                                                NaN
#
#                                      Q5_3  \
# 0                                     NaN
# 1    EHLM-02-Cross Cultural Communication
# 2                      EEC-01-Game Theory
# 3                                     NaN
# 4                                     NaN
# ..                                    ...
# 545                                   NaN
# 546                                   NaN
# 547                                   NaN
# 548                                   NaN
# 549                                   NaN
#
#                                       Q5_4  \
# 0                                      NaN
# 1                   EFM-03-Project Finance
# 2    EFM-01-Advanced Management Accounting
# 3                                      NaN
# 4                                      NaN
# ..                                     ...
# 545                                    NaN
# 546                                    NaN
# 547                                    NaN
# 548                                    NaN
# 549                                    NaN
#
#                                                   Q5_5  \
# 0                                                  NaN
# 1                EFM-01-Advanced Management Accounting
# 2    EFM-02-Security Analysis and Portfolio Management
# 3                                                  NaN
# 4                                                  NaN
# ..                                                 ...
# 545                                                NaN
# 546                                                NaN
# 547                                                NaN
# 548                                                NaN
# 549                                                NaN
#
#                                             Q5_6  \
# 0                                            NaN
# 1    EIT-01-Artificial Intelligence for Business
# 2                         EFM-03-Project Finance
# 3                                            NaN
# 4                                            NaN
# ..                                           ...
# 545                                          NaN
# 546                                          NaN
# 547                                          NaN
# 548                                          NaN
# 549                                          NaN
#
#                              Q6_1  \
# 0                             NaN
# 1    EFM-06-International Finance
# 2    EFM-04-Financial Derivatives
# 3                             NaN
# 4                             NaN
# ..                            ...
# 545                           NaN
# 546                           NaN
# 547                           NaN
# 548                           NaN
# 549                           NaN
#
#                                             Q6_2  \
# 0                                            NaN
# 1               EMM-01-Managing Business Markets
# 2    EFM-05-Management of Financial Institutions
# 3                                            NaN
# 4                                            NaN
# ..                                           ...
# 545                                          NaN
# 546                                          NaN
# 547                                          NaN
# 548                                          NaN
# 549                                          NaN
#
#                               Q6_3                                      Q6_4  \
# 0                              NaN                                       NaN
# 1    EHLM-04-Advanced Business Law  EFM-07-Valuations Mergers & Acquisitions
# 2     EFM-06-International Finance  EFM-07-Valuations Mergers & Acquisitions
# 3                              NaN                                       NaN
# 4                              NaN                                       NaN
# ..                             ...                                       ...
# 545                            NaN                                       NaN
# 546                            NaN                                       NaN
# 547                            NaN                                       NaN
# 548                            NaN                                       NaN
# 549                            NaN                                       NaN
#
#                                     Q6_5  \
# 0                                    NaN
# 1               EMM-08-Digital Marketing
# 2    EHLM-03-Understanding Public Policy
# 3                                    NaN
# 4                                    NaN
# ..                                   ...
# 545                                  NaN
# 546                                  NaN
# 547                                  NaN
# 548                                  NaN
# 549                                  NaN
#
#                                        Q6_6                            Q7_1  \
# 0                                       NaN                             NaN
# 1    EHR-03-Performance & Talent Management  EFM-10-Entrepreneurial Finance
# 2             EHLM-04-Advanced Business Law              EEC-01-Game Theory
# 3                                       NaN                             NaN
# 4                                       NaN                             NaN
# ..                                      ...                             ...
# 545                                     NaN                             NaN
# 546                                     NaN                             NaN
# 547                                     NaN                             NaN
# 548                                     NaN                             NaN
# 549                                     NaN                             NaN
#
#                                                   Q7_2  \
# 0                                                  NaN
# 1    EHLM-05-Social Media – Communication and Business
# 2                  EFM-08-Financial Statement Analysis
# 3                                                  NaN
# 4                                                  NaN
# ..                                                 ...
# 545                                                NaN
# 546                                                NaN
# 547                                                NaN
# 548                                                NaN
# 549                                                NaN
#
#                                       Q7_3  \
# 0                                      NaN
# 1     EOM-07-Service Operations Management
# 2    EFM-09-Strategic Financial Management
# 3                                      NaN
# 4                                      NaN
# ..                                     ...
# 545                                    NaN
# 546                                    NaN
# 547                                    NaN
# 548                                    NaN
# 549                                    NaN
#
#                                              Q7_4  \
# 0                                             NaN
# 1    EHLM-06-Democracy, Politics and Institutions
# 2                  EFM-10-Entrepreneurial Finance
# 3                                             NaN
# 4                                             NaN
# ..                                            ...
# 545                                           NaN
# 546                                           NaN
# 547                                           NaN
# 548                                           NaN
# 549                                           NaN
#
#                                                   Q7_5  \
# 0                                                  NaN
# 1                                    ESM-10-Consulting
# 2    EHLM-05-Social Media – Communication and Business
# 3                                                  NaN
# 4                                                  NaN
# ..                                                 ...
# 545                                                NaN
# 546                                                NaN
# 547                                                NaN
# 548                                                NaN
# 549                                                NaN
#
#                                              Q7_6
# 0                                             NaN
# 1             EFM-08-Financial Statement Analysis
# 2    EHLM-06-Democracy, Politics and Institutions
# 3                                             NaN
# 4                                             NaN
# ..                                            ...
# 545                                           NaN
# 546                                           NaN
# 547                                           NaN
# 548                                           NaN
# 549                                           NaN
#
# [550 rows x 20 columns]

# %%
list = ['EPGP-15A-004','EPGP-15A-004' ,'EEC-02-Introduction to Public Policy', 'EEC-03-Agent-Based Modelling for Business and Management', 'EEC-01-Game Theory', 'EFM-01-Advanced Management Accounting', 'EFM-02-Security Analysis and Portfolio Management', 'EFM-03-Project Finance', 'EFM-04-Financial Derivatives', 'EFM-05-Management of Financial Institutions', 'EFM-06-International Finance', 'EFM-07-Valuations Mergers & Acquisitions', 'EHLM-03-Understanding Public Policy', 'EHLM-04-Advanced Business Law', 'EEC-01-Game Theory', 'EFM-08-Financial Statement Analysis', 'EFM-09-Strategic Financial Management', 'EFM-10-Entrepreneurial Finance', 'EHLM-05-Social Media – Communication and Business', 'EHLM-06-Democracy, Politics and Institutions']
selected_buttons1 = 'EPGP-15A-004'

student_details.loc[student_details['Roll'] == selected_buttons1] = list
student_details
# Out:
#              Roll          Name  \
# 0    EPGP-15A-001  EPGP-15A-001
# 1    EPGP-15A-002  EPGP-15A-002
# 2    EPGP-15A-003  EPGP-15A-003
# 3    EPGP-15A-004  EPGP-15A-004
# 4    EPGP-15A-005  EPGP-15A-005
# ..            ...           ...
# 545  EPGP-15E-106  EPGP-15E-106
# 546  EPGP-15E-107  EPGP-15E-107
# 547  EPGP-15E-108  EPGP-15E-108
# 548  EPGP-15E-109  EPGP-15E-109
# 549  EPGP-15E-110  EPGP-15E-110
#
#                                                   Q5_1  \
# 0                                                  NaN
# 1    EEC-03-Agent-Based Modelling for Business and ...
# 2                 EEC-02-Introduction to Public Policy
# 3                 EEC-02-Introduction to Public Policy
# 4                                                  NaN
# ..                                                 ...
# 545                                                NaN
# 546                                                NaN
# 547                                                NaN
# 548                                                NaN
# 549                                                NaN
#
#                                                   Q5_2  \
# 0                                                  NaN
# 1    EHLM-01-Advanced Corporate Communication: The ...
# 2    EEC-03-Agent-Based Modelling for Business and ...
# 3    EEC-03-Agent-Based Modelling for Business and ...
# 4                                                  NaN
# ..                                                 ...
# 545                                                NaN
# 546                                                NaN
# 547                                                NaN
# 548                                                NaN
# 549                                                NaN
#
#                                      Q5_3  \
# 0                                     NaN
# 1    EHLM-02-Cross Cultural Communication
# 2                      EEC-01-Game Theory
# 3                      EEC-01-Game Theory
# 4                                     NaN
# ..                                    ...
# 545                                   NaN
# 546                                   NaN
# 547                                   NaN
# 548                                   NaN
# 549                                   NaN
#
#                                       Q5_4  \
# 0                                      NaN
# 1                   EFM-03-Project Finance
# 2    EFM-01-Advanced Management Accounting
# 3    EFM-01-Advanced Management Accounting
# 4                                      NaN
# ..                                     ...
# 545                                    NaN
# 546                                    NaN
# 547                                    NaN
# 548                                    NaN
# 549                                    NaN
#
#                                                   Q5_5  \
# 0                                                  NaN
# 1                EFM-01-Advanced Management Accounting
# 2    EFM-02-Security Analysis and Portfolio Management
# 3    EFM-02-Security Analysis and Portfolio Management
# 4                                                  NaN
# ..                                                 ...
# 545                                                NaN
# 546                                                NaN
# 547                                                NaN
# 548                                                NaN
# 549                                                NaN
#
#                                             Q5_6  \
# 0                                            NaN
# 1    EIT-01-Artificial Intelligence for Business
# 2                         EFM-03-Project Finance
# 3                         EFM-03-Project Finance
# 4                                            NaN
# ..                                           ...
# 545                                          NaN
# 546                                          NaN
# 547                                          NaN
# 548                                          NaN
# 549                                          NaN
#
#                              Q6_1  \
# 0                             NaN
# 1    EFM-06-International Finance
# 2    EFM-04-Financial Derivatives
# 3    EFM-04-Financial Derivatives
# 4                             NaN
# ..                            ...
# 545                           NaN
# 546                           NaN
# 547                           NaN
# 548                           NaN
# 549                           NaN
#
#                                             Q6_2  \
# 0                                            NaN
# 1               EMM-01-Managing Business Markets
# 2    EFM-05-Management of Financial Institutions
# 3    EFM-05-Management of Financial Institutions
# 4                                            NaN
# ..                                           ...
# 545                                          NaN
# 546                                          NaN
# 547                                          NaN
# 548                                          NaN
# 549                                          NaN
#
#                               Q6_3                                      Q6_4  \
# 0                              NaN                                       NaN
# 1    EHLM-04-Advanced Business Law  EFM-07-Valuations Mergers & Acquisitions
# 2     EFM-06-International Finance  EFM-07-Valuations Mergers & Acquisitions
# 3     EFM-06-International Finance  EFM-07-Valuations Mergers & Acquisitions
# 4                              NaN                                       NaN
# ..                             ...                                       ...
# 545                            NaN                                       NaN
# 546                            NaN                                       NaN
# 547                            NaN                                       NaN
# 548                            NaN                                       NaN
# 549                            NaN                                       NaN
#
#                                     Q6_5  \
# 0                                    NaN
# 1               EMM-08-Digital Marketing
# 2    EHLM-03-Understanding Public Policy
# 3    EHLM-03-Understanding Public Policy
# 4                                    NaN
# ..                                   ...
# 545                                  NaN
# 546                                  NaN
# 547                                  NaN
# 548                                  NaN
# 549                                  NaN
#
#                                        Q6_6                            Q7_1  \
# 0                                       NaN                             NaN
# 1    EHR-03-Performance & Talent Management  EFM-10-Entrepreneurial Finance
# 2             EHLM-04-Advanced Business Law              EEC-01-Game Theory
# 3             EHLM-04-Advanced Business Law              EEC-01-Game Theory
# 4                                       NaN                             NaN
# ..                                      ...                             ...
# 545                                     NaN                             NaN
# 546                                     NaN                             NaN
# 547                                     NaN                             NaN
# 548                                     NaN                             NaN
# 549                                     NaN                             NaN
#
#                                                   Q7_2  \
# 0                                                  NaN
# 1    EHLM-05-Social Media – Communication and Business
# 2                  EFM-08-Financial Statement Analysis
# 3                  EFM-08-Financial Statement Analysis
# 4                                                  NaN
# ..                                                 ...
# 545                                                NaN
# 546                                                NaN
# 547                                                NaN
# 548                                                NaN
# 549                                                NaN
#
#                                       Q7_3  \
# 0                                      NaN
# 1     EOM-07-Service Operations Management
# 2    EFM-09-Strategic Financial Management
# 3    EFM-09-Strategic Financial Management
# 4                                      NaN
# ..                                     ...
# 545                                    NaN
# 546                                    NaN
# 547                                    NaN
# 548                                    NaN
# 549                                    NaN
#
#                                              Q7_4  \
# 0                                             NaN
# 1    EHLM-06-Democracy, Politics and Institutions
# 2                  EFM-10-Entrepreneurial Finance
# 3                  EFM-10-Entrepreneurial Finance
# 4                                             NaN
# ..                                            ...
# 545                                           NaN
# 546                                           NaN
# 547                                           NaN
# 548                                           NaN
# 549                                           NaN
#
#                                                   Q7_5  \
# 0                                                  NaN
# 1                                    ESM-10-Consulting
# 2    EHLM-05-Social Media – Communication and Business
# 3    EHLM-05-Social Media – Communication and Business
# 4                                                  NaN
# ..                                                 ...
# 545                                                NaN
# 546                                                NaN
# 547                                                NaN
# 548                                                NaN
# 549                                                NaN
#
#                                              Q7_6
# 0                                             NaN
# 1             EFM-08-Financial Statement Analysis
# 2    EHLM-06-Democracy, Politics and Institutions
# 3    EHLM-06-Democracy, Politics and Institutions
# 4                                             NaN
# ..                                            ...
# 545                                           NaN
# 546                                           NaN
# 547                                           NaN
# 548                                           NaN
# 549                                           NaN
#
# [550 rows x 20 columns]

# %%
A = [1,2,3,4,5,6]
B = [3, 5, 7, 9]
C = (set(A).intersection(B))
sorted(C)
# Out:
# [3, 5]

# %%
A = student_details.loc[0, :].values.flatten().tolist()
B = student_details.loc[4, :].values.flatten().tolist()
C = (set(A).intersection(B))
D = sorted(C)
len(D)
D
# Out:
# ['EEC-01-Game Theory',
#  'EEC-02-Introduction to Public Policy',
#  'EEC-03-Agent-Based Modelling for Business and Management',
#  'EFM-01-Advanced Management Accounting',
#  'EFM-02-Security Analysis and Portfolio Management',
#  'EFM-03-Project Finance',
#  'EFM-05-Management of Financial Institutions',
#  'EFM-06-International Finance',
#  'EFM-07-Valuations Mergers & Acquisitions',
#  'EFM-08-Financial Statement Analysis',
#  'EFM-09-Strategic Financial Management',
#  'EFM-10-Entrepreneurial Finance',
#  'EHLM-03-Understanding Public Policy',
#  'EHLM-04-Advanced Business Law',
#  'EHLM-05-Social Media – Communication and Business',
#  'EHLM-06-Democracy, Politics and Institutions',
#  'EIT-04-Natural Language Processing for Business']

# %%
with pd.ExcelWriter('student_details.xlsx') as writer:
            student_details.to_excel(writer, sheet_name  = 'Sheet_1')

# %%
run Trail1.py
# Out:
# ---------------------------------------------------------------------------
# NoLayoutException                         Traceback (most recent call last)
# File /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/flask/app.py:865, in Flask.full_dispatch_request(self=<Flask 'Trail1'>)
#     863 try:
#     864     request_started.send(self, _async_wrapper=self.ensure_sync)
# --> 865     rv = self.preprocess_request()
#         self = <Flask 'Trail1'>
#     866     if rv is None:
#     867         rv = self.dispatch_request()
#
# File /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/flask/app.py:1239, in Flask.preprocess_request(self=<Flask 'Trail1'>)
#    1237 if name in self.before_request_funcs:
#    1238     for before_func in self.before_request_funcs[name]:
# -> 1239         rv = self.ensure_sync(before_func)()
#         before_func = <bound method Dash._setup_server of <dash.dash.Dash object at 0x1342bc150>>
#         self = <Flask 'Trail1'>
#    1241         if rv is not None:
#    1242             return rv
#
# File /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/dash/dash.py:1343, in Dash._setup_server(self=<dash.dash.Dash object>)
#    1340 if not self.layout and self.use_pages:
#    1341     self.layout = page_container
# -> 1343 _validate.validate_layout(self.layout, self._layout_value())
#         self = <dash.dash.Dash object at 0x1342bc150>
#         _validate = <module 'dash._validate' from '/Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/dash/_validate.py'>
#    1345 self._generate_scripts_html()
#    1346 self._generate_css_dist_html()
#
# File /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/dash/_validate.py:402, in validate_layout(layout=None, layout_value=None)
#     400 def validate_layout(layout, layout_value):
#     401     if layout is None:
# --> 402         raise exceptions.NoLayoutException(
#         exceptions = <module 'dash.exceptions' from '/Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/dash/exceptions.py'>
#     403             """
#     404             The layout was `None` at the time that `run_server` was called.
#     405             Make sure to set the `layout` attribute of your application
#     406             before running the server.
#     407             """
#     408         )
#     410     layout_id = stringify_id(getattr(layout_value, "id", None))
#     412     component_ids = {layout_id} if layout_id else set()
#
# NoLayoutException: The layout was `None` at the time that `run_server` was called.
# Make sure to set the `layout` attribute of your application
# before running the server.
#         <iframe
#             width="100%"
#             height="650"
#             src="http://127.0.0.1:8051/"
#             frameborder="0"
#             allowfullscreen
#
#         ></iframe>
# ---------------------------------------------------------------------------
# AssertionError                            Traceback (most recent call last)
# File ~/Desktop/Data Analytics/Common Course/Trail1.py:110
#     105     return f'Selected buttons: {selected_buttons1+selected_buttons1+selected_buttons2+selected_buttons3+selected_buttons4+selected_buttons5}', n_clicks
#     109 if __name__ == '__main__':
# --> 110     app.run_server(debug=True)
#
# File /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/dash/dash.py:2175, in Dash.run_server(self, *args, **kwargs)
#    2169 def run_server(self, *args, **kwargs):
#    2170     """`run_server` is a deprecated alias of `run` and may be removed in a
#    2171     future version. We recommend using `app.run` instead.
#    2172
#    2173     See `app.run` for usage information.
#    2174     """
# -> 2175     self.run(*args, **kwargs)
#
# File /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/dash/dash.py:1997, in Dash.run(self, host, port, proxy, debug, jupyter_mode, jupyter_width, jupyter_height, jupyter_server_url, dev_tools_ui, dev_tools_props_check, dev_tools_serve_dev_bundles, dev_tools_hot_reload, dev_tools_hot_reload_interval, dev_tools_hot_reload_watch_interval, dev_tools_hot_reload_max_retry, dev_tools_silence_routes_logging, dev_tools_prune_errors, **flask_run_options)
#    1994 if debug is None:
#    1995     debug = get_combined_config("debug", None, False)
# -> 1997 debug = self.enable_dev_tools(
#    1998     debug,
#    1999     dev_tools_ui,
#    2000     dev_tools_props_check,
#    2001     dev_tools_serve_dev_bundles,
#    2002     dev_tools_hot_reload,
#    2003     dev_tools_hot_reload_interval,
#    2004     dev_tools_hot_reload_watch_interval,
#    2005     dev_tools_hot_reload_max_retry,
#    2006     dev_tools_silence_routes_logging,
#    2007     dev_tools_prune_errors,
#    2008 )
#    2010 # Verify port value
#    2011 try:
#
# File /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/dash/dash.py:1767, in Dash.enable_dev_tools(self, debug, dev_tools_ui, dev_tools_props_check, dev_tools_serve_dev_bundles, dev_tools_hot_reload, dev_tools_hot_reload_interval, dev_tools_hot_reload_watch_interval, dev_tools_hot_reload_max_retry, dev_tools_silence_routes_logging, dev_tools_prune_errors)
#    1765 if debug:
#    1766     if jupyter_dash.active:
# -> 1767         jupyter_dash.configure_callback_exception_handling(
#    1768             self, dev_tools.prune_errors
#    1769         )
#    1770     elif dev_tools.prune_errors:
#    1771         secret = gen_salt(20)
#
# File /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/dash/_jupyter.py:443, in JupyterDash.configure_callback_exception_handling(self, app, dev_tools_prune_errors)
#     440 def configure_callback_exception_handling(self, app, dev_tools_prune_errors):
#     441     """Install traceback handling for callbacks"""
# --> 443     @app.server.errorhandler(Exception)
#     444     def _wrap_errors(error):
#     445         # Compute number of stack frames to skip to get down to callback
#     446         skip = _get_skip(error) if dev_tools_prune_errors else 0
#     448         # Customized formatargvalues function we can place function parameters
#     449         # on separate lines
#
# File /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/flask/sansio/scaffold.py:43, in setupmethod.<locals>.wrapper_func(self, *args, **kwargs)
#      42 def wrapper_func(self, *args: t.Any, **kwargs: t.Any) -> t.Any:
# ---> 43     self._check_setup_finished(f_name)
#      44     return f(self, *args, **kwargs)
#
# File /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/flask/sansio/app.py:417, in App._check_setup_finished(self, f_name)
#     415 def _check_setup_finished(self, f_name: str) -> None:
#     416     if self._got_first_request:
# --> 417         raise AssertionError(
#     418             f"The setup method '{f_name}' can no longer be called"
#     419             " on the application. It has already handled its first"
#     420             " request, any changes will not be applied"
#     421             " consistently.\n"
#     422             "Make sure all imports, decorators, functions, etc."
#     423             " needed to set up the application are done before"
#     424             " running it."
#     425         )
#
# AssertionError: The setup method 'errorhandler' can no longer be called on the application. It has already handled its first request, any changes will not be applied consistently.
# Make sure all imports, decorators, functions, etc. needed to set up the application are done before running it.

# %%
student_details
# Out:
#              Roll          Name  \
# 0    EPGP-15A-001  EPGP-15A-001
# 1    EPGP-15A-002  EPGP-15A-002
# 2    EPGP-15A-003  EPGP-15A-003
# 3    EPGP-15A-004  EPGP-15A-004
# 4    EPGP-15A-005  EPGP-15A-005
# ..            ...           ...
# 545  EPGP-15E-106  EPGP-15E-106
# 546  EPGP-15E-107  EPGP-15E-107
# 547  EPGP-15E-108  EPGP-15E-108
# 548  EPGP-15E-109  EPGP-15E-109
# 549  EPGP-15E-110  EPGP-15E-110
#
#                                                   Q5_1  \
# 0                                                  NaN
# 1    EEC-03-Agent-Based Modelling for Business and ...
# 2                                                  NaN
# 3                                                  NaN
# 4                                                  NaN
# ..                                                 ...
# 545                                                NaN
# 546                                                NaN
# 547                                                NaN
# 548                                                NaN
# 549                                                NaN
#
#                                                   Q5_2  \
# 0                                                  NaN
# 1    EHLM-01-Advanced Corporate Communication: The ...
# 2                                                  NaN
# 3                                                  NaN
# 4                                                  NaN
# ..                                                 ...
# 545                                                NaN
# 546                                                NaN
# 547                                                NaN
# 548                                                NaN
# 549                                                NaN
#
#                                      Q5_3                    Q5_4  \
# 0                                     NaN                     NaN
# 1    EHLM-02-Cross Cultural Communication  EFM-03-Project Finance
# 2                                     NaN                     NaN
# 3                                     NaN                     NaN
# 4                                     NaN                     NaN
# ..                                    ...                     ...
# 545                                   NaN                     NaN
# 546                                   NaN                     NaN
# 547                                   NaN                     NaN
# 548                                   NaN                     NaN
# 549                                   NaN                     NaN
#
#                                       Q5_5  \
# 0                                      NaN
# 1    EFM-01-Advanced Management Accounting
# 2                                      NaN
# 3                                      NaN
# 4                                      NaN
# ..                                     ...
# 545                                    NaN
# 546                                    NaN
# 547                                    NaN
# 548                                    NaN
# 549                                    NaN
#
#                                             Q5_6  \
# 0                                            NaN
# 1    EIT-01-Artificial Intelligence for Business
# 2                                            NaN
# 3                                            NaN
# 4                                            NaN
# ..                                           ...
# 545                                          NaN
# 546                                          NaN
# 547                                          NaN
# 548                                          NaN
# 549                                          NaN
#
#                              Q6_1                              Q6_2  \
# 0                             NaN                               NaN
# 1    EFM-06-International Finance  EMM-01-Managing Business Markets
# 2                             NaN                               NaN
# 3                             NaN                               NaN
# 4                             NaN                               NaN
# ..                            ...                               ...
# 545                           NaN                               NaN
# 546                           NaN                               NaN
# 547                           NaN                               NaN
# 548                           NaN                               NaN
# 549                           NaN                               NaN
#
#                               Q6_3                                      Q6_4  \
# 0                              NaN                                       NaN
# 1    EHLM-04-Advanced Business Law  EFM-07-Valuations Mergers & Acquisitions
# 2                              NaN                                       NaN
# 3                              NaN                                       NaN
# 4                              NaN                                       NaN
# ..                             ...                                       ...
# 545                            NaN                                       NaN
# 546                            NaN                                       NaN
# 547                            NaN                                       NaN
# 548                            NaN                                       NaN
# 549                            NaN                                       NaN
#
#                          Q6_5                                    Q6_6  \
# 0                         NaN                                     NaN
# 1    EMM-08-Digital Marketing  EHR-03-Performance & Talent Management
# 2                         NaN                                     NaN
# 3                         NaN                                     NaN
# 4                         NaN                                     NaN
# ..                        ...                                     ...
# 545                       NaN                                     NaN
# 546                       NaN                                     NaN
# 547                       NaN                                     NaN
# 548                       NaN                                     NaN
# 549                       NaN                                     NaN
#
#                                Q7_1  \
# 0                               NaN
# 1    EFM-10-Entrepreneurial Finance
# 2                               NaN
# 3                               NaN
# 4                               NaN
# ..                              ...
# 545                             NaN
# 546                             NaN
# 547                             NaN
# 548                             NaN
# 549                             NaN
#
#                                                   Q7_2  \
# 0                                                  NaN
# 1    EHLM-05-Social Media – Communication and Business
# 2                                                  NaN
# 3                                                  NaN
# 4                                                  NaN
# ..                                                 ...
# 545                                                NaN
# 546                                                NaN
# 547                                                NaN
# 548                                                NaN
# 549                                                NaN
#
#                                      Q7_3  \
# 0                                     NaN
# 1    EOM-07-Service Operations Management
# 2                                     NaN
# 3                                     NaN
# 4                                     NaN
# ..                                    ...
# 545                                   NaN
# 546                                   NaN
# 547                                   NaN
# 548                                   NaN
# 549                                   NaN
#
#                                              Q7_4               Q7_5  \
# 0                                             NaN                NaN
# 1    EHLM-06-Democracy, Politics and Institutions  ESM-10-Consulting
# 2                                             NaN                NaN
# 3                                             NaN                NaN
# 4                                             NaN                NaN
# ..                                            ...                ...
# 545                                           NaN                NaN
# 546                                           NaN                NaN
# 547                                           NaN                NaN
# 548                                           NaN                NaN
# 549                                           NaN                NaN
#
#                                     Q7_6
# 0                                    NaN
# 1    EFM-08-Financial Statement Analysis
# 2                                    NaN
# 3                                    NaN
# 4                                    NaN
# ..                                   ...
# 545                                  NaN
# 546                                  NaN
# 547                                  NaN
# 548                                  NaN
# 549                                  NaN
#
# [550 rows x 20 columns]

# %%
student_details
# Out:
#              Roll          Name  \
# 0    EPGP-15A-001  EPGP-15A-001
# 1    EPGP-15A-002  EPGP-15A-002
# 2    EPGP-15A-003  EPGP-15A-003
# 3    EPGP-15A-004  EPGP-15A-004
# 4    EPGP-15A-005  EPGP-15A-005
# ..            ...           ...
# 545  EPGP-15E-106  EPGP-15E-106
# 546  EPGP-15E-107  EPGP-15E-107
# 547  EPGP-15E-108  EPGP-15E-108
# 548  EPGP-15E-109  EPGP-15E-109
# 549  EPGP-15E-110  EPGP-15E-110
#
#                                                   Q5_1  \
# 0                                                  NaN
# 1    EEC-03-Agent-Based Modelling for Business and ...
# 2                                                  NaN
# 3                                                  NaN
# 4                                                  NaN
# ..                                                 ...
# 545                                                NaN
# 546                                                NaN
# 547                                                NaN
# 548                                                NaN
# 549                                                NaN
#
#                                                   Q5_2  \
# 0                                                  NaN
# 1    EHLM-01-Advanced Corporate Communication: The ...
# 2                                                  NaN
# 3                                                  NaN
# 4                                                  NaN
# ..                                                 ...
# 545                                                NaN
# 546                                                NaN
# 547                                                NaN
# 548                                                NaN
# 549                                                NaN
#
#                                      Q5_3                    Q5_4  \
# 0                                     NaN                     NaN
# 1    EHLM-02-Cross Cultural Communication  EFM-03-Project Finance
# 2                                     NaN                     NaN
# 3                                     NaN                     NaN
# 4                                     NaN                     NaN
# ..                                    ...                     ...
# 545                                   NaN                     NaN
# 546                                   NaN                     NaN
# 547                                   NaN                     NaN
# 548                                   NaN                     NaN
# 549                                   NaN                     NaN
#
#                                       Q5_5  \
# 0                                      NaN
# 1    EFM-01-Advanced Management Accounting
# 2                                      NaN
# 3                                      NaN
# 4                                      NaN
# ..                                     ...
# 545                                    NaN
# 546                                    NaN
# 547                                    NaN
# 548                                    NaN
# 549                                    NaN
#
#                                             Q5_6  \
# 0                                            NaN
# 1    EIT-01-Artificial Intelligence for Business
# 2                                            NaN
# 3                                            NaN
# 4                                            NaN
# ..                                           ...
# 545                                          NaN
# 546                                          NaN
# 547                                          NaN
# 548                                          NaN
# 549                                          NaN
#
#                              Q6_1                              Q6_2  \
# 0                             NaN                               NaN
# 1    EFM-06-International Finance  EMM-01-Managing Business Markets
# 2                             NaN                               NaN
# 3                             NaN                               NaN
# 4                             NaN                               NaN
# ..                            ...                               ...
# 545                           NaN                               NaN
# 546                           NaN                               NaN
# 547                           NaN                               NaN
# 548                           NaN                               NaN
# 549                           NaN                               NaN
#
#                               Q6_3                                      Q6_4  \
# 0                              NaN                                       NaN
# 1    EHLM-04-Advanced Business Law  EFM-07-Valuations Mergers & Acquisitions
# 2                              NaN                                       NaN
# 3                              NaN                                       NaN
# 4                              NaN                                       NaN
# ..                             ...                                       ...
# 545                            NaN                                       NaN
# 546                            NaN                                       NaN
# 547                            NaN                                       NaN
# 548                            NaN                                       NaN
# 549                            NaN                                       NaN
#
#                          Q6_5                                    Q6_6  \
# 0                         NaN                                     NaN
# 1    EMM-08-Digital Marketing  EHR-03-Performance & Talent Management
# 2                         NaN                                     NaN
# 3                         NaN                                     NaN
# 4                         NaN                                     NaN
# ..                        ...                                     ...
# 545                       NaN                                     NaN
# 546                       NaN                                     NaN
# 547                       NaN                                     NaN
# 548                       NaN                                     NaN
# 549                       NaN                                     NaN
#
#                                Q7_1  \
# 0                               NaN
# 1    EFM-10-Entrepreneurial Finance
# 2                               NaN
# 3                               NaN
# 4                               NaN
# ..                              ...
# 545                             NaN
# 546                             NaN
# 547                             NaN
# 548                             NaN
# 549                             NaN
#
#                                                   Q7_2  \
# 0                                                  NaN
# 1    EHLM-05-Social Media – Communication and Business
# 2                                                  NaN
# 3                                                  NaN
# 4                                                  NaN
# ..                                                 ...
# 545                                                NaN
# 546                                                NaN
# 547                                                NaN
# 548                                                NaN
# 549                                                NaN
#
#                                      Q7_3  \
# 0                                     NaN
# 1    EOM-07-Service Operations Management
# 2                                     NaN
# 3                                     NaN
# 4                                     NaN
# ..                                    ...
# 545                                   NaN
# 546                                   NaN
# 547                                   NaN
# 548                                   NaN
# 549                                   NaN
#
#                                              Q7_4               Q7_5  \
# 0                                             NaN                NaN
# 1    EHLM-06-Democracy, Politics and Institutions  ESM-10-Consulting
# 2                                             NaN                NaN
# 3                                             NaN                NaN
# 4                                             NaN                NaN
# ..                                            ...                ...
# 545                                           NaN                NaN
# 546                                           NaN                NaN
# 547                                           NaN                NaN
# 548                                           NaN                NaN
# 549                                           NaN                NaN
#
#                                     Q7_6
# 0                                    NaN
# 1    EFM-08-Financial Statement Analysis
# 2                                    NaN
# 3                                    NaN
# 4                                    NaN
# ..                                   ...
# 545                                  NaN
# 546                                  NaN
# 547                                  NaN
# 548                                  NaN
# 549                                  NaN
#
# [550 rows x 20 columns]

# %%
del student_details[student_details. columns[0]] 
student_details
# Out:
#                        Q5_4                                   Q5_5  \
# 0                       NaN                                    NaN
# 1    EFM-03-Project Finance  EFM-01-Advanced Management Accounting
# 2                       NaN                                    NaN
# 3                       NaN                                    NaN
# 4                       NaN                                    NaN
# ..                      ...                                    ...
# 545                     NaN                                    NaN
# 546                     NaN                                    NaN
# 547                     NaN                                    NaN
# 548                     NaN                                    NaN
# 549                     NaN                                    NaN
#
#                                             Q5_6  \
# 0                                            NaN
# 1    EIT-01-Artificial Intelligence for Business
# 2                                            NaN
# 3                                            NaN
# 4                                            NaN
# ..                                           ...
# 545                                          NaN
# 546                                          NaN
# 547                                          NaN
# 548                                          NaN
# 549                                          NaN
#
#                              Q6_1                              Q6_2  \
# 0                             NaN                               NaN
# 1    EFM-06-International Finance  EMM-01-Managing Business Markets
# 2                             NaN                               NaN
# 3                             NaN                               NaN
# 4                             NaN                               NaN
# ..                            ...                               ...
# 545                           NaN                               NaN
# 546                           NaN                               NaN
# 547                           NaN                               NaN
# 548                           NaN                               NaN
# 549                           NaN                               NaN
#
#                               Q6_3                                      Q6_4  \
# 0                              NaN                                       NaN
# 1    EHLM-04-Advanced Business Law  EFM-07-Valuations Mergers & Acquisitions
# 2                              NaN                                       NaN
# 3                              NaN                                       NaN
# 4                              NaN                                       NaN
# ..                             ...                                       ...
# 545                            NaN                                       NaN
# 546                            NaN                                       NaN
# 547                            NaN                                       NaN
# 548                            NaN                                       NaN
# 549                            NaN                                       NaN
#
#                          Q6_5                                    Q6_6  \
# 0                         NaN                                     NaN
# 1    EMM-08-Digital Marketing  EHR-03-Performance & Talent Management
# 2                         NaN                                     NaN
# 3                         NaN                                     NaN
# 4                         NaN                                     NaN
# ..                        ...                                     ...
# 545                       NaN                                     NaN
# 546                       NaN                                     NaN
# 547                       NaN                                     NaN
# 548                       NaN                                     NaN
# 549                       NaN                                     NaN
#
#                                Q7_1  \
# 0                               NaN
# 1    EFM-10-Entrepreneurial Finance
# 2                               NaN
# 3                               NaN
# 4                               NaN
# ..                              ...
# 545                             NaN
# 546                             NaN
# 547                             NaN
# 548                             NaN
# 549                             NaN
#
#                                                   Q7_2  \
# 0                                                  NaN
# 1    EHLM-05-Social Media – Communication and Business
# 2                                                  NaN
# 3                                                  NaN
# 4                                                  NaN
# ..                                                 ...
# 545                                                NaN
# 546                                                NaN
# 547                                                NaN
# 548                                                NaN
# 549                                                NaN
#
#                                      Q7_3  \
# 0                                     NaN
# 1    EOM-07-Service Operations Management
# 2                                     NaN
# 3                                     NaN
# 4                                     NaN
# ..                                    ...
# 545                                   NaN
# 546                                   NaN
# 547                                   NaN
# 548                                   NaN
# 549                                   NaN
#
#                                              Q7_4               Q7_5  \
# 0                                             NaN                NaN
# 1    EHLM-06-Democracy, Politics and Institutions  ESM-10-Consulting
# 2                                             NaN                NaN
# 3                                             NaN                NaN
# 4                                             NaN                NaN
# ..                                            ...                ...
# 545                                           NaN                NaN
# 546                                           NaN                NaN
# 547                                           NaN                NaN
# 548                                           NaN                NaN
# 549                                           NaN                NaN
#
#                                     Q7_6
# 0                                    NaN
# 1    EFM-08-Financial Statement Analysis
# 2                                    NaN
# 3                                    NaN
# 4                                    NaN
# ..                                   ...
# 545                                  NaN
# 546                                  NaN
# 547                                  NaN
# 548                                  NaN
# 549                                  NaN
#
# [550 rows x 15 columns]

# %%
pd.read_excel('student_details.xlsx',index_col = 0)
# Out:
#              Roll          Name  \
# 0    EPGP-15A-001  EPGP-15A-001
# 1    EPGP-15A-002  EPGP-15A-002
# 2    EPGP-15A-003  EPGP-15A-003
# 3    EPGP-15A-004  EPGP-15A-004
# 4    EPGP-15A-005  EPGP-15A-005
# ..            ...           ...
# 545  EPGP-15E-106  EPGP-15E-106
# 546  EPGP-15E-107  EPGP-15E-107
# 547  EPGP-15E-108  EPGP-15E-108
# 548  EPGP-15E-109  EPGP-15E-109
# 549  EPGP-15E-110  EPGP-15E-110
#
#                                                   Q5_1  \
# 0                                                  NaN
# 1    EEC-03-Agent-Based Modelling for Business and ...
# 2                 EEC-02-Introduction to Public Policy
# 3                 EEC-02-Introduction to Public Policy
# 4                                                  NaN
# ..                                                 ...
# 545                                                NaN
# 546                                                NaN
# 547                                                NaN
# 548                                                NaN
# 549                                                NaN
#
#                                                   Q5_2  \
# 0                                                  NaN
# 1    EHLM-01-Advanced Corporate Communication: The ...
# 2    EEC-03-Agent-Based Modelling for Business and ...
# 3    EEC-03-Agent-Based Modelling for Business and ...
# 4                                                  NaN
# ..                                                 ...
# 545                                                NaN
# 546                                                NaN
# 547                                                NaN
# 548                                                NaN
# 549                                                NaN
#
#                                      Q5_3  \
# 0                                     NaN
# 1    EHLM-02-Cross Cultural Communication
# 2                      EEC-01-Game Theory
# 3                      EEC-01-Game Theory
# 4                                     NaN
# ..                                    ...
# 545                                   NaN
# 546                                   NaN
# 547                                   NaN
# 548                                   NaN
# 549                                   NaN
#
#                                       Q5_4  \
# 0                                      NaN
# 1                   EFM-03-Project Finance
# 2    EFM-01-Advanced Management Accounting
# 3    EFM-01-Advanced Management Accounting
# 4                                      NaN
# ..                                     ...
# 545                                    NaN
# 546                                    NaN
# 547                                    NaN
# 548                                    NaN
# 549                                    NaN
#
#                                                   Q5_5  \
# 0                                                  NaN
# 1                EFM-01-Advanced Management Accounting
# 2    EFM-02-Security Analysis and Portfolio Management
# 3    EFM-02-Security Analysis and Portfolio Management
# 4                                                  NaN
# ..                                                 ...
# 545                                                NaN
# 546                                                NaN
# 547                                                NaN
# 548                                                NaN
# 549                                                NaN
#
#                                             Q5_6  \
# 0                                            NaN
# 1    EIT-01-Artificial Intelligence for Business
# 2                         EFM-03-Project Finance
# 3                         EFM-03-Project Finance
# 4                                            NaN
# ..                                           ...
# 545                                          NaN
# 546                                          NaN
# 547                                          NaN
# 548                                          NaN
# 549                                          NaN
#
#                              Q6_1  \
# 0                             NaN
# 1    EFM-06-International Finance
# 2    EFM-04-Financial Derivatives
# 3    EFM-04-Financial Derivatives
# 4                             NaN
# ..                            ...
# 545                           NaN
# 546                           NaN
# 547                           NaN
# 548                           NaN
# 549                           NaN
#
#                                             Q6_2  \
# 0                                            NaN
# 1               EMM-01-Managing Business Markets
# 2    EFM-05-Management of Financial Institutions
# 3    EFM-05-Management of Financial Institutions
# 4                                            NaN
# ..                                           ...
# 545                                          NaN
# 546                                          NaN
# 547                                          NaN
# 548                                          NaN
# 549                                          NaN
#
#                               Q6_3                                      Q6_4  \
# 0                              NaN                                       NaN
# 1    EHLM-04-Advanced Business Law  EFM-07-Valuations Mergers & Acquisitions
# 2     EFM-06-International Finance  EFM-07-Valuations Mergers & Acquisitions
# 3     EFM-06-International Finance  EFM-07-Valuations Mergers & Acquisitions
# 4                              NaN                                       NaN
# ..                             ...                                       ...
# 545                            NaN                                       NaN
# 546                            NaN                                       NaN
# 547                            NaN                                       NaN
# 548                            NaN                                       NaN
# 549                            NaN                                       NaN
#
#                                     Q6_5  \
# 0                                    NaN
# 1               EMM-08-Digital Marketing
# 2    EHLM-03-Understanding Public Policy
# 3    EHLM-03-Understanding Public Policy
# 4                                    NaN
# ..                                   ...
# 545                                  NaN
# 546                                  NaN
# 547                                  NaN
# 548                                  NaN
# 549                                  NaN
#
#                                        Q6_6                            Q7_1  \
# 0                                       NaN                             NaN
# 1    EHR-03-Performance & Talent Management  EFM-10-Entrepreneurial Finance
# 2             EHLM-04-Advanced Business Law              EEC-01-Game Theory
# 3             EHLM-04-Advanced Business Law              EEC-01-Game Theory
# 4                                       NaN                             NaN
# ..                                      ...                             ...
# 545                                     NaN                             NaN
# 546                                     NaN                             NaN
# 547                                     NaN                             NaN
# 548                                     NaN                             NaN
# 549                                     NaN                             NaN
#
#                                                   Q7_2  \
# 0                                                  NaN
# 1    EHLM-05-Social Media – Communication and Business
# 2                  EFM-08-Financial Statement Analysis
# 3                  EFM-08-Financial Statement Analysis
# 4                                                  NaN
# ..                                                 ...
# 545                                                NaN
# 546                                                NaN
# 547                                                NaN
# 548                                                NaN
# 549                                                NaN
#
#                                       Q7_3  \
# 0                                      NaN
# 1     EOM-07-Service Operations Management
# 2    EFM-09-Strategic Financial Management
# 3    EFM-09-Strategic Financial Management
# 4                                      NaN
# ..                                     ...
# 545                                    NaN
# 546                                    NaN
# 547                                    NaN
# 548                                    NaN
# 549                                    NaN
#
#                                              Q7_4  \
# 0                                             NaN
# 1    EHLM-06-Democracy, Politics and Institutions
# 2                  EFM-10-Entrepreneurial Finance
# 3                  EFM-10-Entrepreneurial Finance
# 4                                             NaN
# ..                                            ...
# 545                                           NaN
# 546                                           NaN
# 547                                           NaN
# 548                                           NaN
# 549                                           NaN
#
#                                                   Q7_5  \
# 0                                                  NaN
# 1                                    ESM-10-Consulting
# 2    EHLM-05-Social Media – Communication and Business
# 3    EHLM-05-Social Media – Communication and Business
# 4                                                  NaN
# ..                                                 ...
# 545                                                NaN
# 546                                                NaN
# 547                                                NaN
# 548                                                NaN
# 549                                                NaN
#
#                                              Q7_6
# 0                                             NaN
# 1             EFM-08-Financial Statement Analysis
# 2    EHLM-06-Democracy, Politics and Institutions
# 3    EHLM-06-Democracy, Politics and Institutions
# 4                                             NaN
# ..                                            ...
# 545                                           NaN
# 546                                           NaN
# 547                                           NaN
# 548                                           NaN
# 549                                           NaN
#
# [550 rows x 20 columns]
